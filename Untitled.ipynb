# %%
# %run -i 'get_pr_pair_description.py'
# Out:
# finish write /DATA/shurui/pr_data/mozilla-b2g/gaia/1737/api.json to file....
# finish write /DATA/shurui/pr_data/mozilla-b2g/gaia/24863/api.json to file....
# finish write /DATA/shurui/pr_data/scikit-learn/scikit-learn/8698/api.json to file....
# finish write /DATA/shurui/pr_data/scikit-learn/scikit-learn/10132/api.json to file....
# finish write /DATA/shurui/pr_data/symfony/symfony/17855/api.json to file....
# finish write /DATA/shurui/pr_data/symfony/symfony/21470/api.json to file....
# finish write /DATA/shurui/pr_data/kubernetes/kubernetes/21448/api.json to file....
# finish write /DATA/shurui/pr_data/kubernetes/kubernetes/16034/api.json to file....
# finish write /DATA/shurui/pr_data/nodejs/node/10316/api.json to file....
# finish write /DATA/shurui/pr_data/nodejs/node/17685/api.json to file....
# finish write /DATA/shurui/pr_data/pydata/pandas/19943/api.json to file....
# finish write /DATA/shurui/pr_data/pydata/pandas/20872/api.json to file....
# ...
